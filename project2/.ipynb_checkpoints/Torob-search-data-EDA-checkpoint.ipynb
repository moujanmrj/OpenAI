# %% [markdown]
# <img style="float: right;" src="attachment:04f31c53-483e-4bae-a4ef-aeed484c3692.png">
#
# # Exploratory Analysis of Torob Search Data
#
# Greetings and a warm welcome from Torob Data Team!
#
# We are very excited to share with you the Torob's search data for the task of exploratory data analysis as part of OpenAI Summer School 2022. The data consists of users' search logs as well as their clicks on search results in Torob. It also includes information for a sample of the products and product categories. In this notebook, you will analyze this data and answer some questions with the goal of practicing your data analysis skills (especially the ability to work with Pandas) and also extract insightful information from our users' searches and their interaction with the search results.
#
# Note that our original daily search data is very large (you may need gigabytes of RAM and disk space to handle the data of just one day!). So, for practical purposes and due to the size constraints, the original data has been sampled and reduced, and what you'll work with is just a small fraction of the data of one week.
#
# The sections marked with a triangular flag (🚩) are those which you need to read and answer. Allright, without further ado let's get started!
#
# (NOTE: Here is the link to the guideline document of the project: https://docs.google.com/document/d/1r46gWcSXwvxxpS92cOqqA7pLuX1Vq673rokgwtnafb8/edit?usp=sharing)

# %% [markdown]
# ---

# %% [markdown]
# ## Import modules/libraries
#
# So, as usual, we first need to import the neccessary libraries and modules which we would use:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ---

# %% [markdown]
# ## Load and Inspect Data
#
# In this section we load the data from given files, and then we take a quick look at their structure and make sure they have been loaded properly.

# %% [markdown]
# ### 🚩Load data from disk
#
# First, we need to load the data from disk as Pandas dataframes. There are four different dataframes which need to be loaded:
# - Search logs, stored in `search_logs.pkl`.
# - Search click logs, stored in `search_click_logs.pkl`.
# - Products info, stored in `products.pkl`.
# - Product categories info, stored in `categories.pkl`.
#
# Let's load them all and store each of them in a separate variable:

# %% [markdown]
# **Write the answer below:** \
# (Hint: Since they are stored as *pickled* files, we can easily use `pd.read_pickle` function.)

# %%
categories_df = pd.read_pickle('categories.pkl')
products_df = pd.read_pickle('products.pkl')
search_logs_df = pd.read_pickle('search_logs.pkl')
search_click_logs_df = pd.read_pickle('search_click_logs.pkl')

# %% [markdown]
# ### 🚩A quick peek at the data
#
# To quickly get a feel of the strucure of the data and see if it has been loaded correctly, we can check the first few rows of the dataframes. Let's take a look at the first five rows of each dataframe we loaded in the previous step:

# %% [markdown]
# **Write the answer below:** \
# (Hint: heads or tails?!)

# %%
categories_df.head()
# Out:
#                        title    id  parent_category_id
# 0                گوشی موبایل  2580               175.0
# 1                       تبلت  9458               175.0
# 2      هدفون، هدست و هندزفری  1092               175.0
# 3  لوازم جانبی موبایل و تبلت  8192               175.0
# 4        قطعات موبایل و تبلت  3596               175.0

# %%
products_df.head()
# Out:
#         id                                        title  category_id
# 0   758287                  میکروسکوپ سلسترون مدل 44121          262
# 1  7164195      دوربین عکاسی نیکون مدل Nikon D5600 body         1273
# 2  3242621  دوچرخه شهری قناری مدل Space Shuttle سایز 16         3882
# 3  4277974   دوچرخه سایز 16 مدل  2020 Flying Bear قناری         3882
# 4  8671305                    دوچرخه 12 قناری مدل JENNY         4320

# %%
search_logs_df.head()
# Out:
#       id          raw_query  \
# 0  qahft  سرویس ملامین نشکن
# 1  rxcka          جارو برقی
# 2  fnafq          دسته ps4
# 3  ofpva       کلو تریمازول
# 4  usiey      قرص فولی کوژن
#
#                                               result  \
# 0  [7840591, 1784875, 6716428, 6135112, 7103618, ...
# 1  [451703, 8801989, 8977506, 4665205, 5219768, 5...
# 2  [1457782, 5150503, 5921870, 909372, 9738201, 1...
# 3  [404198, 812389, 339213, 929557, 3632184, 7764...
# 4  [8103652, 7283604, 4030781, 4756913, 3259566, ...
#
#                           datetime  category_id user_id
# 0 2022-05-16 13:17:22.701000+00:00          NaN   MPOHZ
# 1 2022-05-18 11:24:02.385000+00:00       4792.0   NZPJN
# 2 2022-05-14 19:35:31.691000+00:00          NaN   NRMQA
# 3 2022-05-14 18:20:55.328000+00:00          NaN   WRYZT
# 4 2022-05-13 19:50:03.519000+00:00       3196.0   TJLWU

# %%
search_click_logs_df.head()
# Out:
#       id                         datetime search_id  rank
# 0  jstyz 2022-05-13 19:30:14.030000+00:00     iitnm     1
# 1  ewusk 2022-05-13 19:30:24.290000+00:00     scjlb     2
# 2  osnio 2022-05-13 19:30:24.394000+00:00     ohuqq     6
# 3  expgi 2022-05-13 19:30:30.500000+00:00     pzrcn     3
# 4  srgdy 2022-05-13 19:30:32.884000+00:00     mhlmr     5

# %% [markdown]
# ---

# %% [markdown]
# ## Data Validation
#
# Before starting our analysis, it's a good practice to validate the consistency of the data values and constraints with our expectations. There are various validity checks that could be done, and below we give you two examples.

# %% [markdown]
# ### 🚩Validate uniquness of ID columns
#
# For example, we can confirm whether all the unique ID columns (i.e. `id` column) have no duplicate values for all the dataframes we have. Let's check this for all the four dataframes:

# %% [markdown]
# **Write the answer below:**

# %%
categories_df.id.duplicated().sum()
# Out:
# 0

# %%
products_df.id.duplicated().sum()
# Out:
# 0

# %%
search_logs_df.id.duplicated().sum()
# Out:
# 0

# %%
search_click_logs_df.id.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 🚩Validate all the search clicks have a valid rank value
#
# Here, we would like to check two things about the rank of search click records: 1) they have no NaN value, 2) they are all between 0 and 9 (because searches have at most 10 results). Let's do these checks:

# %% [markdown]
# **Write the answer below:**

# %%
search_click_logs_df.isna().sum()
# Out:
# id             0
# datetime       0
# search_id      0
# rank           0
# day_of_week    0
# hours          0
# dtype: int64

# %%
search_click_logs_df['rank'].max()
# Out:
# 9

# %%
search_click_logs_df['rank'].min()
# Out:
# 0

# %% [markdown]
# ---

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# Now that we have loaded the data, we are ready to start the processing and analysis of our data.

# %% [markdown]
# ### 🚩Number of searches and search clicks
#
# The most basic stat we can get from our data is the number of searches and search clicks we have. Let's find and print them:

# %% [markdown]
# **Write the answer below:**

# %%
search_click_logs_df.shape[0]
# Out:
# 295692

# %%
search_logs_df.shape[0]
# Out:
# 539289

# %% [markdown]
# ### 🚩Number of unique search queries
#
# We can also calculate the number of unique search queries.

# %% [markdown]
# **Write the answer below:**

# %%
search_click_logs_df['id'].nunique()
# Out:
# 295692

# %% [markdown]
# ### 🚩Number of unique users
#
# Another basic stat is the number of unique users who searched on Torob. We can use `user_id` column to calculate this:

# %% [markdown]
# **Write the answer below:**

# %%
search_logs_df['user_id'].nunique()
# Out:
# 311083

# %% [markdown]
# ### 🚩Most frequent search queries
#
# We would like to know which search queries are the most popular (i.e. most frequent). We can use the "search logs" data to find the answer. Find the top 20 most searched queries along with their number of searches:

# %% [markdown]
# **Write the answer below:**

# %%
search_logs_df['raw_query'].value_counts()[:20].to_frame()
# Out:
#                raw_query
# iphone              7626
# دلار امریکا         3240
# کفش                 3211
# روغن                2956
# لپ تاپ ایسوس        1940
# دوربین عکاسی        1929
# شیر                 1781
# دوچرخه 26           1689
# xbox series s       1617
# لباس عروس           1577
# گوشی                1454
# روغن موتور          1333
# ماکروویو            1196
# xiaomi 12 pro       1083
# کاغذ a4             1012
# تلویزیون             843
# گوشی سامسونگ         812
# دوچرخه               807
# یخچال                789
# روغن خوراکی          787

# %% [markdown]
# ### 🚩Distribution of length of search queries
#
# We expect that the majority of search queries consist of at most three words. Let's confirm our expectation by calculating the number of words in each search query and then aggregate these values to see how the length of queries is distributed (i.e. find the distribution of number of words in search queries):

# %% [markdown]
# **Write the answer below:**
# (Hint: for the sake of simplicity, you can assume that in each search query the words are separated from each other by one or more whitespace characters. Yes, we know this is a simplification and has errors, but it's a good approximation. Further, note that the `str` acessor in Pandas gives you a lot of good methods for processing columns of type string and list.)

# %%
sl_df = search_logs_df
sl_df['number of words'] = search_logs_df['raw_query'].str.split().str.len()
sl_df
# Out:
#            id          raw_query  \
# 0       qahft  سرویس ملامین نشکن
# 1       rxcka          جارو برقی
# 2       fnafq          دسته ps4
# 3       ofpva       کلو تریمازول
# 4       usiey      قرص فولی کوژن
# ...       ...                ...
# 539284  komsy     گیره تزیینی مو
# 539285  rgtin  دراپ بنر بی تی اس
# 539286  ouixi    مینی فرز رونیکس
# 539287  cnemi               t295
# 539288  afnwn       سرویس قابلمه
#
#                                                    result  \
# 0       [7840591, 1784875, 6716428, 6135112, 7103618, ...
# 1       [451703, 8801989, 8977506, 4665205, 5219768, 5...
# 2       [1457782, 5150503, 5921870, 909372, 9738201, 1...
# 3       [404198, 812389, 339213, 929557, 3632184, 7764...
# 4       [8103652, 7283604, 4030781, 4756913, 3259566, ...
# ...                                                   ...
# 539284  [5453845, 8144670, 929409, 2560009, 2945123, 1...
# 539285  [4651071, 7207811, 3198227, 5668360, 3934514, ...
# 539286  [3627110, 6731253, 3386983, 678951, 5285940, 3...
# 539287  [3789177, 1968708, 459464, 5077881, 6612780, 1...
# 539288  [7674912, 3037094, 3876156, 8439562, 746455, 4...
#
#                                datetime  category_id user_id  number of words
# 0      2022-05-16 13:17:22.701000+00:00          NaN   MPOHZ                3
# 1      2022-05-18 11:24:02.385000+00:00       4792.0   NZPJN                2
# 2      2022-05-14 19:35:31.691000+00:00          NaN   NRMQA                2
# 3      2022-05-14 18:20:55.328000+00:00          NaN   WRYZT                2
# 4      2022-05-13 19:50:03.519000+00:00       3196.0   TJLWU                3
# ...                                 ...          ...     ...              ...
# 539284 2022-05-17 11:40:45.256000+00:00          NaN   HBGXD                3
# 539285 2022-05-16 17:22:19.306000+00:00          NaN   RKJDP                5
# 539286 2022-05-18 11:55:34.127000+00:00          NaN   QGIDE                3
# 539287 2022-05-14 10:50:27.468000+00:00          NaN   XHCNF                1
# 539288 2022-05-17 10:59:08.572000+00:00          NaN   MVVMZ                2
#
# [539289 rows x 7 columns]

# %%
sl_df['number of words'].value_counts()
# Out:
# 2    213446
# 3    140200
# 1    138518
# 4     42003
# 5      4791
# 6       325
# 7         6
# Name: number of words, dtype: int64

# %%
plt.hist(sl_df['number of words'])
plt.title('Distribution of number of words in search queries')
plt.xlabel('Number of words')
plt.ylabel('Number of queries')
plt.show()

# %% [markdown]
# ### 🚩Most common words in search queries
#
# Which words were most commonly used in the search queries? Find the top 20 most common words along with their number of occurrences in search queries:

# %% [markdown]
# **Write the answer below:**
# (Hint: split + explode!!!)

# %%
sl_df['words'] = search_logs_df['raw_query'].str.split()
sl_df
# Out:
#            id          raw_query  \
# 0       qahft  سرویس ملامین نشکن
# 1       rxcka          جارو برقی
# 2       fnafq          دسته ps4
# 3       ofpva       کلو تریمازول
# 4       usiey      قرص فولی کوژن
# ...       ...                ...
# 539284  komsy     گیره تزیینی مو
# 539285  rgtin  دراپ بنر بی تی اس
# 539286  ouixi    مینی فرز رونیکس
# 539287  cnemi               t295
# 539288  afnwn       سرویس قابلمه
#
#                                                    result  \
# 0       [7840591, 1784875, 6716428, 6135112, 7103618, ...
# 1       [451703, 8801989, 8977506, 4665205, 5219768, 5...
# 2       [1457782, 5150503, 5921870, 909372, 9738201, 1...
# 3       [404198, 812389, 339213, 929557, 3632184, 7764...
# 4       [8103652, 7283604, 4030781, 4756913, 3259566, ...
# ...                                                   ...
# 539284  [5453845, 8144670, 929409, 2560009, 2945123, 1...
# 539285  [4651071, 7207811, 3198227, 5668360, 3934514, ...
# 539286  [3627110, 6731253, 3386983, 678951, 5285940, 3...
# 539287  [3789177, 1968708, 459464, 5077881, 6612780, 1...
# 539288  [7674912, 3037094, 3876156, 8439562, 746455, 4...
#
#                                datetime  category_id user_id  number of words  \
# 0      2022-05-16 13:17:22.701000+00:00          NaN   MPOHZ                3
# 1      2022-05-18 11:24:02.385000+00:00       4792.0   NZPJN                2
# 2      2022-05-14 19:35:31.691000+00:00          NaN   NRMQA                2
# 3      2022-05-14 18:20:55.328000+00:00          NaN   WRYZT                2
# 4      2022-05-13 19:50:03.519000+00:00       3196.0   TJLWU                3
# ...                                 ...          ...     ...              ...
# 539284 2022-05-17 11:40:45.256000+00:00          NaN   HBGXD                3
# 539285 2022-05-16 17:22:19.306000+00:00          NaN   RKJDP                5
# 539286 2022-05-18 11:55:34.127000+00:00          NaN   QGIDE                3
# 539287 2022-05-14 10:50:27.468000+00:00          NaN   XHCNF                1
# 539288 2022-05-17 10:59:08.572000+00:00          NaN   MVVMZ                2
#
#                           words
# 0         [سرویس, ملامین, نشکن]
# 1                  [جارو, برقی]
# 2                   [دسته, ps4]
# 3               [کلو, تریمازول]
# 4             [قرص, فولی, کوژن]
# ...                         ...
# 539284       [گیره, تزیینی, مو]
# 539285  [دراپ, بنر, بی, تی, اس]
# 539286      [مینی, فرز, رونیکس]
# 539287                   [t295]
# 539288          [سرویس, قابلمه]
#
# [539289 rows x 8 columns]

# %%
df1 = sl_df.explode('words')
df1
# Out:
#            id          raw_query  \
# 0       qahft  سرویس ملامین نشکن
# 0       qahft  سرویس ملامین نشکن
# 0       qahft  سرویس ملامین نشکن
# 1       rxcka          جارو برقی
# 1       rxcka          جارو برقی
# ...       ...                ...
# 539286  ouixi    مینی فرز رونیکس
# 539286  ouixi    مینی فرز رونیکس
# 539287  cnemi               t295
# 539288  afnwn       سرویس قابلمه
# 539288  afnwn       سرویس قابلمه
#
#                                                    result  \
# 0       [7840591, 1784875, 6716428, 6135112, 7103618, ...
# 0       [7840591, 1784875, 6716428, 6135112, 7103618, ...
# 0       [7840591, 1784875, 6716428, 6135112, 7103618, ...
# 1       [451703, 8801989, 8977506, 4665205, 5219768, 5...
# 1       [451703, 8801989, 8977506, 4665205, 5219768, 5...
# ...                                                   ...
# 539286  [3627110, 6731253, 3386983, 678951, 5285940, 3...
# 539286  [3627110, 6731253, 3386983, 678951, 5285940, 3...
# 539287  [3789177, 1968708, 459464, 5077881, 6612780, 1...
# 539288  [7674912, 3037094, 3876156, 8439562, 746455, 4...
# 539288  [7674912, 3037094, 3876156, 8439562, 746455, 4...
#
#                                datetime  category_id user_id  number of words  \
# 0      2022-05-16 13:17:22.701000+00:00          NaN   MPOHZ                3
# 0      2022-05-16 13:17:22.701000+00:00          NaN   MPOHZ                3
# 0      2022-05-16 13:17:22.701000+00:00          NaN   MPOHZ                3
# 1      2022-05-18 11:24:02.385000+00:00       4792.0   NZPJN                2
# 1      2022-05-18 11:24:02.385000+00:00       4792.0   NZPJN                2
# ...                                 ...          ...     ...              ...
# 539286 2022-05-18 11:55:34.127000+00:00          NaN   QGIDE                3
# 539286 2022-05-18 11:55:34.127000+00:00          NaN   QGIDE                3
# 539287 2022-05-14 10:50:27.468000+00:00          NaN   XHCNF                1
# 539288 2022-05-17 10:59:08.572000+00:00          NaN   MVVMZ                2
# 539288 2022-05-17 10:59:08.572000+00:00          NaN   MVVMZ                2
#
#          words
# 0        سرویس
# 0       ملامین
# 0         نشکن
# 1         جارو
# 1         برقی
# ...        ...
# 539286     فرز
# 539286  رونیکس
# 539287    t295
# 539288   سرویس
# 539288  قابلمه
#
# [1179969 rows x 8 columns]

# %%
df1['words'].value_counts()[:20].to_frame()
# Out:
#          words
# گوشی     12606
# روغن     11010
# iphone    9228
# موتور     8039
# کفش       7933
# pro       6381
# دوچرخه    6094
# سامسونگ   5598
# لباس      5334
# ماشین     5266
# ساعت      5132
# پراید     5110
# کولر      4777
# ای        4418
# برقی      4400
# تاپ       4180
# مردانه    4096
# یخچال     4040
# دوربین    4026
# لپ        3987

# %% [markdown]
# ### 🚩Localize date and time values
#
# Currently, the date & time values in the search and search-click dataframes are stored in UTC timezone. This is a best-pratice to store timestamp values in UTC when the data is stored in databases; however, for our next time-based analyses to be more understandable, we need to convert them all to Tehran timezone.
#
# Convert and replace the `datetime` columns in both search and search-click dataframes:

# %% [markdown]
# **Write the answer below:**
# (Hint: in Pandas, datetime columns have a `dt` accessor which offers some methods for manipulation of datetime values. Here, you should look for `tz_convert` method and use `'Asia/Tehran'` as the timezone.)

# %%
search_click_df = search_click_logs_df
search_click_df['datetime'] = search_click_df['datetime'].dt.tz_convert(tz='Asia/Tehran') 
search_click_df
# Out:
#            id                         datetime search_id  rank
# 0       jstyz 2022-05-14 00:00:14.030000+04:30     iitnm     1
# 1       ewusk 2022-05-14 00:00:24.290000+04:30     scjlb     2
# 2       osnio 2022-05-14 00:00:24.394000+04:30     ohuqq     6
# 3       expgi 2022-05-14 00:00:30.500000+04:30     pzrcn     3
# 4       srgdy 2022-05-14 00:00:32.884000+04:30     mhlmr     5
# ...       ...                              ...       ...   ...
# 295687  ekdor 2022-05-20 23:59:54.307000+04:30     yacmw     4
# 295688  rxpwg 2022-05-20 23:59:56.579000+04:30     keqas     1
# 295689  newqm 2022-05-20 23:59:56.804000+04:30     vpksd     8
# 295690  ksvlv 2022-05-20 23:59:57.718000+04:30     prptj     2
# 295691  fanez 2022-05-20 23:59:58.992000+04:30     wvsqc     1
#
# [295692 rows x 4 columns]

# %%
search_df = search_logs_df
search_df['datetime'] = search_df['datetime'].dt.tz_convert(tz='Asia/Tehran') 
search_df
# Out:
#            id          raw_query  \
# 0       qahft  سرویس ملامین نشکن
# 1       rxcka          جارو برقی
# 2       fnafq          دسته ps4
# 3       ofpva       کلو تریمازول
# 4       usiey      قرص فولی کوژن
# ...       ...                ...
# 539284  komsy     گیره تزیینی مو
# 539285  rgtin  دراپ بنر بی تی اس
# 539286  ouixi    مینی فرز رونیکس
# 539287  cnemi               t295
# 539288  afnwn       سرویس قابلمه
#
#                                                    result  \
# 0       [7840591, 1784875, 6716428, 6135112, 7103618, ...
# 1       [451703, 8801989, 8977506, 4665205, 5219768, 5...
# 2       [1457782, 5150503, 5921870, 909372, 9738201, 1...
# 3       [404198, 812389, 339213, 929557, 3632184, 7764...
# 4       [8103652, 7283604, 4030781, 4756913, 3259566, ...
# ...                                                   ...
# 539284  [5453845, 8144670, 929409, 2560009, 2945123, 1...
# 539285  [4651071, 7207811, 3198227, 5668360, 3934514, ...
# 539286  [3627110, 6731253, 3386983, 678951, 5285940, 3...
# 539287  [3789177, 1968708, 459464, 5077881, 6612780, 1...
# 539288  [7674912, 3037094, 3876156, 8439562, 746455, 4...
#
#                                datetime  category_id user_id  number of words  \
# 0      2022-05-16 17:47:22.701000+04:30          NaN   MPOHZ                3
# 1      2022-05-18 15:54:02.385000+04:30       4792.0   NZPJN                2
# 2      2022-05-15 00:05:31.691000+04:30          NaN   NRMQA                2
# 3      2022-05-14 22:50:55.328000+04:30          NaN   WRYZT                2
# 4      2022-05-14 00:20:03.519000+04:30       3196.0   TJLWU                3
# ...                                 ...          ...     ...              ...
# 539284 2022-05-17 16:10:45.256000+04:30          NaN   HBGXD                3
# 539285 2022-05-16 21:52:19.306000+04:30          NaN   RKJDP                5
# 539286 2022-05-18 16:25:34.127000+04:30          NaN   QGIDE                3
# 539287 2022-05-14 15:20:27.468000+04:30          NaN   XHCNF                1
# 539288 2022-05-17 15:29:08.572000+04:30          NaN   MVVMZ                2
#
#                           words
# 0         [سرویس, ملامین, نشکن]
# 1                  [جارو, برقی]
# 2                   [دسته, ps4]
# 3               [کلو, تریمازول]
# 4             [قرص, فولی, کوژن]
# ...                         ...
# 539284       [گیره, تزیینی, مو]
# 539285  [دراپ, بنر, بی, تی, اس]
# 539286      [مینی, فرز, رونیکس]
# 539287                   [t295]
# 539288          [سرویس, قابلمه]
#
# [539289 rows x 8 columns]

# %% [markdown]
# ### 🚩Number of searches and search-clicks per weekday
#
# Now that we have converted the datetime to Tehran timezone, we are interested to know how many searches and search-clicks exist per weekday (i.e. Saturday, Sunday, Monday, etc.). We expect that both of these numbers to be a bit lower on weekends (i.e. Thursday and Friday).
#
# Calculate the number of searches and search-clicks per weekday and plot both alongside each other in a single bar plot:

# %% [markdown]
# **Write the answer below:**
# (Hint: again, you can use the methods which exist via `dt` accessor to get the weekday of datetime values. As a challenge, try to write all the calculations and plotting in just a single python statement by using method chaining... a lot!)

# %%
search_click_df2 = search_click_df
search_click_df2['day_of_week'] = search_click_df['datetime'].dt.day_name()
search_click_df2
# Out:
#            id                         datetime search_id  rank day_of_week
# 0       jstyz 2022-05-14 00:00:14.030000+04:30     iitnm     1    Saturday
# 1       ewusk 2022-05-14 00:00:24.290000+04:30     scjlb     2    Saturday
# 2       osnio 2022-05-14 00:00:24.394000+04:30     ohuqq     6    Saturday
# 3       expgi 2022-05-14 00:00:30.500000+04:30     pzrcn     3    Saturday
# 4       srgdy 2022-05-14 00:00:32.884000+04:30     mhlmr     5    Saturday
# ...       ...                              ...       ...   ...         ...
# 295687  ekdor 2022-05-20 23:59:54.307000+04:30     yacmw     4      Friday
# 295688  rxpwg 2022-05-20 23:59:56.579000+04:30     keqas     1      Friday
# 295689  newqm 2022-05-20 23:59:56.804000+04:30     vpksd     8      Friday
# 295690  ksvlv 2022-05-20 23:59:57.718000+04:30     prptj     2      Friday
# 295691  fanez 2022-05-20 23:59:58.992000+04:30     wvsqc     1      Friday
#
# [295692 rows x 5 columns]

# %%
req_day = search_click_df2["day_of_week"].value_counts()
req_day
# Out:
# Saturday     43760
# Tuesday      42781
# Monday       42733
# Sunday       42234
# Wednesday    42139
# Thursday     41257
# Friday       40788
# Name: day_of_week, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
days_ = ['Saturday', 'Tuesday', 'Monday', 'Sunday', 'Wednesday', 'Thursday', 'Friday']
reqs = req_day[0:7]
ax.bar(days_,reqs)
plt.show()

# %%
search_df2 = search_df
search_df2['day_of_week'] = search_df['datetime'].dt.day_name()
search_df2
# Out:
#            id          raw_query  \
# 0       qahft  سرویس ملامین نشکن
# 1       rxcka          جارو برقی
# 2       fnafq          دسته ps4
# 3       ofpva       کلو تریمازول
# 4       usiey      قرص فولی کوژن
# ...       ...                ...
# 539284  komsy     گیره تزیینی مو
# 539285  rgtin  دراپ بنر بی تی اس
# 539286  ouixi    مینی فرز رونیکس
# 539287  cnemi               t295
# 539288  afnwn       سرویس قابلمه
#
#                                                    result  \
# 0       [7840591, 1784875, 6716428, 6135112, 7103618, ...
# 1       [451703, 8801989, 8977506, 4665205, 5219768, 5...
# 2       [1457782, 5150503, 5921870, 909372, 9738201, 1...
# 3       [404198, 812389, 339213, 929557, 3632184, 7764...
# 4       [8103652, 7283604, 4030781, 4756913, 3259566, ...
# ...                                                   ...
# 539284  [5453845, 8144670, 929409, 2560009, 2945123, 1...
# 539285  [4651071, 7207811, 3198227, 5668360, 3934514, ...
# 539286  [3627110, 6731253, 3386983, 678951, 5285940, 3...
# 539287  [3789177, 1968708, 459464, 5077881, 6612780, 1...
# 539288  [7674912, 3037094, 3876156, 8439562, 746455, 4...
#
#                                datetime  category_id user_id  number of words  \
# 0      2022-05-16 17:47:22.701000+04:30          NaN   MPOHZ                3
# 1      2022-05-18 15:54:02.385000+04:30       4792.0   NZPJN                2
# 2      2022-05-15 00:05:31.691000+04:30          NaN   NRMQA                2
# 3      2022-05-14 22:50:55.328000+04:30          NaN   WRYZT                2
# 4      2022-05-14 00:20:03.519000+04:30       3196.0   TJLWU                3
# ...                                 ...          ...     ...              ...
# 539284 2022-05-17 16:10:45.256000+04:30          NaN   HBGXD                3
# 539285 2022-05-16 21:52:19.306000+04:30          NaN   RKJDP                5
# 539286 2022-05-18 16:25:34.127000+04:30          NaN   QGIDE                3
# 539287 2022-05-14 15:20:27.468000+04:30          NaN   XHCNF                1
# 539288 2022-05-17 15:29:08.572000+04:30          NaN   MVVMZ                2
#
#                           words day_of_week
# 0         [سرویس, ملامین, نشکن]      Monday
# 1                  [جارو, برقی]   Wednesday
# 2                   [دسته, ps4]      Sunday
# 3               [کلو, تریمازول]    Saturday
# 4             [قرص, فولی, کوژن]    Saturday
# ...                         ...         ...
# 539284       [گیره, تزیینی, مو]     Tuesday
# 539285  [دراپ, بنر, بی, تی, اس]      Monday
# 539286      [مینی, فرز, رونیکس]   Wednesday
# 539287                   [t295]    Saturday
# 539288          [سرویس, قابلمه]     Tuesday
#
# [539289 rows x 9 columns]

# %%
req_day_ = search_df2["day_of_week"].value_counts()
req_day_
# Out:
# Saturday     80032
# Tuesday      79031
# Monday       77720
# Wednesday    77305
# Sunday       77021
# Thursday     74457
# Friday       73723
# Name: day_of_week, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
days_ = ['Saturday', 'Tuesday', 'Monday', 'Sunday', 'Wednesday', 'Thursday', 'Friday']
reqs = req_day_[0:7]
ax.bar(days_,reqs)
plt.show()

# %%
search_df2["day_of_week"].value_counts().plot.bar()
search_click_df2["day_of_week"].value_counts().plot.bar(color='orange')
plt.show()

# %% [markdown]
# ### 🚩Number of searches and search-clicks per hour of day
#
# Next, we would like to know which hour during the day has the most search traffic.
#
# Calculate the number of searches and search-clicks per hour and plot both alongside each other in a single bar plot (note that we are just interested in the hour regardless of the specific day; so the result should be aggregated based on hour **over all the days**):

# %% [markdown]
# **Write the answer below:**
# (Hint: again, `dt` accessor is your friend here as well!)

# %%
search_click_df2['hours'] = search_click_df['datetime'].dt.hour
search_click_df2
# Out:
#            id                         datetime search_id  rank day_of_week  \
# 0       jstyz 2022-05-14 00:00:14.030000+04:30     iitnm     1    Saturday
# 1       ewusk 2022-05-14 00:00:24.290000+04:30     scjlb     2    Saturday
# 2       osnio 2022-05-14 00:00:24.394000+04:30     ohuqq     6    Saturday
# 3       expgi 2022-05-14 00:00:30.500000+04:30     pzrcn     3    Saturday
# 4       srgdy 2022-05-14 00:00:32.884000+04:30     mhlmr     5    Saturday
# ...       ...                              ...       ...   ...         ...
# 295687  ekdor 2022-05-20 23:59:54.307000+04:30     yacmw     4      Friday
# 295688  rxpwg 2022-05-20 23:59:56.579000+04:30     keqas     1      Friday
# 295689  newqm 2022-05-20 23:59:56.804000+04:30     vpksd     8      Friday
# 295690  ksvlv 2022-05-20 23:59:57.718000+04:30     prptj     2      Friday
# 295691  fanez 2022-05-20 23:59:58.992000+04:30     wvsqc     1      Friday
#
#         hours
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 295687     23
# 295688     23
# 295689     23
# 295690     23
# 295691     23
#
# [295692 rows x 6 columns]

# %%
req_hour = search_click_df2["hours"].value_counts()
req_hour
# Out:
# 23    19770
# 22    19672
# 21    18155
# 14    17256
# 20    17234
# 13    16988
# 0     16868
# 15    16539
# 12    16070
# 16    15872
# 18    15807
# 19    15796
# 17    15242
# 11    13886
# 1     12413
# 10    11896
# 9      8461
# 2      7491
# 8      5669
# 3      4253
# 7      3572
# 4      2574
# 6      2253
# 5      1955
# Name: hours, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
days_ = list(range(24))
reqs = req_hour[0:24]
ax.bar(days_,reqs)
plt.show()

# %%
search_df2['hours'] = search_df['datetime'].dt.hour
search_df2
# Out:
#            id          raw_query  \
# 0       qahft  سرویس ملامین نشکن
# 1       rxcka          جارو برقی
# 2       fnafq          دسته ps4
# 3       ofpva       کلو تریمازول
# 4       usiey      قرص فولی کوژن
# ...       ...                ...
# 539284  komsy     گیره تزیینی مو
# 539285  rgtin  دراپ بنر بی تی اس
# 539286  ouixi    مینی فرز رونیکس
# 539287  cnemi               t295
# 539288  afnwn       سرویس قابلمه
#
#                                                    result  \
# 0       [7840591, 1784875, 6716428, 6135112, 7103618, ...
# 1       [451703, 8801989, 8977506, 4665205, 5219768, 5...
# 2       [1457782, 5150503, 5921870, 909372, 9738201, 1...
# 3       [404198, 812389, 339213, 929557, 3632184, 7764...
# 4       [8103652, 7283604, 4030781, 4756913, 3259566, ...
# ...                                                   ...
# 539284  [5453845, 8144670, 929409, 2560009, 2945123, 1...
# 539285  [4651071, 7207811, 3198227, 5668360, 3934514, ...
# 539286  [3627110, 6731253, 3386983, 678951, 5285940, 3...
# 539287  [3789177, 1968708, 459464, 5077881, 6612780, 1...
# 539288  [7674912, 3037094, 3876156, 8439562, 746455, 4...
#
#                                datetime  category_id user_id  number of words  \
# 0      2022-05-16 17:47:22.701000+04:30          NaN   MPOHZ                3
# 1      2022-05-18 15:54:02.385000+04:30       4792.0   NZPJN                2
# 2      2022-05-15 00:05:31.691000+04:30          NaN   NRMQA                2
# 3      2022-05-14 22:50:55.328000+04:30          NaN   WRYZT                2
# 4      2022-05-14 00:20:03.519000+04:30       3196.0   TJLWU                3
# ...                                 ...          ...     ...              ...
# 539284 2022-05-17 16:10:45.256000+04:30          NaN   HBGXD                3
# 539285 2022-05-16 21:52:19.306000+04:30          NaN   RKJDP                5
# 539286 2022-05-18 16:25:34.127000+04:30          NaN   QGIDE                3
# 539287 2022-05-14 15:20:27.468000+04:30          NaN   XHCNF                1
# 539288 2022-05-17 15:29:08.572000+04:30          NaN   MVVMZ                2
#
#                           words day_of_week  hours
# 0         [سرویس, ملامین, نشکن]      Monday     17
# 1                  [جارو, برقی]   Wednesday     15
# 2                   [دسته, ps4]      Sunday      0
# 3               [کلو, تریمازول]    Saturday     22
# 4             [قرص, فولی, کوژن]    Saturday      0
# ...                         ...         ...    ...
# 539284       [گیره, تزیینی, مو]     Tuesday     16
# 539285  [دراپ, بنر, بی, تی, اس]      Monday     21
# 539286      [مینی, فرز, رونیکس]   Wednesday     16
# 539287                   [t295]    Saturday     15
# 539288          [سرویس, قابلمه]     Tuesday     15
#
# [539289 rows x 10 columns]

# %%
req_hour_ = search_df2["hours"].value_counts()
req_hour_
# Out:
# 23    34569
# 22    34138
# 21    32007
# 14    31427
# 13    30976
# 15    30501
# 20    30310
# 0     30132
# 12    29872
# 16    28872
# 18    28468
# 19    28453
# 17    28206
# 11    26773
# 10    22510
# 1     22275
# 9     16511
# 2     13611
# 8     11360
# 3      8016
# 7      6886
# 4      5030
# 6      4545
# 5      3841
# Name: hours, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
days_ = list(range(24))
reqs = req_hour_[0:24]
ax.bar(days_,reqs)
plt.show()

# %%
search_df2["hours"].value_counts().plot.bar()
search_click_df2["hours"].value_counts().plot.bar(color='orange')
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
search_df2.assign(hour=search_df2["hours"]).hour.value_counts().sort_index().plot.bar(ax=axes[0])
search_click_df2.assign(hour=search_click_df2["hours"]).hour.value_counts().sort_index().plot.bar(ax=axes[1], color='orange')
plt.rcParams['figure.figsize'] = [20, 7]
plt.show()

# %% [markdown]
# ### 🚩Top 10 most frequent search queries per weekday
#
# Now, instead of calculating the most frequent queries over all the timeframe of the data, we would like to find the top 10 most frequent queries per weekday (note that we don't need the number of searches for each query; we are just interested in the queries themeselves).

# %% [markdown]
# **Write the answer below:**

# %%
search_logs_df.groupby(['day_of_week', 'raw_query']).result.count().groupby('day_of_week', group_keys=False).nlargest(10).to_frame()
# Out:
#                            result
# day_of_week raw_query
# Friday      iphone           1080
#             دلار امریکا       763
#             کفش               467
#             لباس عروس         364
#             شیر               313
# ...                           ...
# Wednesday   روغن              297
#             لپ تاپ ایسوس      262
#             xiaomi 12 pro     252
#             کاغذ a4           245
#             دوربین عکاسی      243
#
# [70 rows x 1 columns]

# %% [markdown]
# ### 🚩Number of searches per user
#
# Next, we would like to know how many of the searches are done by our regular visitors or loyal users.
#
# Calculate the number of searches per user such that we could know the number of users with at most 3 searches, between 4 and 9 searches, and at least 10 searches.

# %% [markdown]
# **Write the answer below:**

# %%
searches_per_user_df = search_logs_df['user_id'].value_counts().to_frame()
searches_per_user_df['bins'] = pd.cut(x=searches_per_user_df['user_id'], bins=[0, 4, 10, float('inf')], right=False, labels=['less than 3', 'between 4 and 9', 'more than 10'])

c = searches_per_user_df['bins'].value_counts()
c
# Out:
# less than 3        286513
# between 4 and 9     22223
# more than 10         2347
# Name: bins, dtype: int64

# %%
plt.bar(c.index, c.values)
plt.show()

# %% [markdown]
# ### 🚩Number of searches with or without a category
#
# For some of the searches, a product category is also selected by the user which limits the search results to only the products in the selected category. We would like to find the number of these searches and compare it against searches without category.
#
# Calculate the number of searches with and without a selected category by users:

# %% [markdown]
# **Write the answer below:**
# (Hint: if `category_id` is `NaN` for a search record, it means that search was performed without selecting a category; and consider that Pandas is very NA-friendly and also has methods for detecting `NaN` values.)

# %%
search_logs_df = search_logs_df.assign(is_category=search_logs_df['category_id'].isna())
search_logs_df.is_category = ~search_logs_df.is_category
search_logs_df
# Out:
#            id          raw_query  \
# 0       qahft  سرویس ملامین نشکن
# 1       rxcka          جارو برقی
# 2       fnafq          دسته ps4
# 3       ofpva       کلو تریمازول
# 4       usiey      قرص فولی کوژن
# ...       ...                ...
# 539284  komsy     گیره تزیینی مو
# 539285  rgtin  دراپ بنر بی تی اس
# 539286  ouixi    مینی فرز رونیکس
# 539287  cnemi               t295
# 539288  afnwn       سرویس قابلمه
#
#                                                    result  \
# 0       [7840591, 1784875, 6716428, 6135112, 7103618, ...
# 1       [451703, 8801989, 8977506, 4665205, 5219768, 5...
# 2       [1457782, 5150503, 5921870, 909372, 9738201, 1...
# 3       [404198, 812389, 339213, 929557, 3632184, 7764...
# 4       [8103652, 7283604, 4030781, 4756913, 3259566, ...
# ...                                                   ...
# 539284  [5453845, 8144670, 929409, 2560009, 2945123, 1...
# 539285  [4651071, 7207811, 3198227, 5668360, 3934514, ...
# 539286  [3627110, 6731253, 3386983, 678951, 5285940, 3...
# 539287  [3789177, 1968708, 459464, 5077881, 6612780, 1...
# 539288  [7674912, 3037094, 3876156, 8439562, 746455, 4...
#
#                                datetime  category_id user_id  number of words  \
# 0      2022-05-16 17:47:22.701000+04:30          NaN   MPOHZ                3
# 1      2022-05-18 15:54:02.385000+04:30       4792.0   NZPJN                2
# 2      2022-05-15 00:05:31.691000+04:30          NaN   NRMQA                2
# 3      2022-05-14 22:50:55.328000+04:30          NaN   WRYZT                2
# 4      2022-05-14 00:20:03.519000+04:30       3196.0   TJLWU                3
# ...                                 ...          ...     ...              ...
# 539284 2022-05-17 16:10:45.256000+04:30          NaN   HBGXD                3
# 539285 2022-05-16 21:52:19.306000+04:30          NaN   RKJDP                5
# 539286 2022-05-18 16:25:34.127000+04:30          NaN   QGIDE                3
# 539287 2022-05-14 15:20:27.468000+04:30          NaN   XHCNF                1
# 539288 2022-05-17 15:29:08.572000+04:30          NaN   MVVMZ                2
#
#                           words day_of_week  hours  is_category
# 0         [سرویس, ملامین, نشکن]      Monday     17        False
# 1                  [جارو, برقی]   Wednesday     15         True
# 2                   [دسته, ps4]      Sunday      0        False
# 3               [کلو, تریمازول]    Saturday     22        False
# 4             [قرص, فولی, کوژن]    Saturday      0         True
# ...                         ...         ...    ...          ...
# 539284       [گیره, تزیینی, مو]     Tuesday     16        False
# 539285  [دراپ, بنر, بی, تی, اس]      Monday     21        False
# 539286      [مینی, فرز, رونیکس]   Wednesday     16        False
# 539287                   [t295]    Saturday     15        False
# 539288          [سرویس, قابلمه]     Tuesday     15        False
#
# [539289 rows x 11 columns]

# %%
search_logs_df.is_category.value_counts().to_frame()
# Out:
#        is_category
# False       410049
# True        129240

# %% [markdown]
# ### 🚩Most frequent search queries among searches with a category
#
# This is the same as the earlier exercise for finding the most frequent search queries, but it only consider searches with a selected category by user.
#
# Find the top 10 most frequent search queries among searches with a category, along with their number of searches:

# %% [markdown]
# **Write the answer below:**

# %%
search_logs_df[search_logs_df['is_category']].raw_query.value_counts()[:10].to_frame()
# Out:
#           raw_query
# روغن           1854
# گوشی            870
# تلویزیون        520
# یخچال           465
# موتور           364
# دوچرخه          325
# کولر            317
# ps5             291
# شیایومی         280
# هارد            280

# %% [markdown]
# ### 🚩Distribution of search clicks over different ranks
#
# Is it more likely that the users click on the top search results instead of the lower ranked results? To find out, we need to compute the distribution of search-clicks over different ranks (i.e. number of search-clicks per rank of the clicked product in the search result).
#
# Plot the distribution of number of search-clicks over different ranks using a bar plot:

# %% [markdown]
# **Write the answer below:**

# %%
search_click_logs_df['rank'].value_counts().plot.bar()
plt.show()

# %% [markdown]
# ### 🚩Number of searches per number of search results
#
# How many of the searches have zero search result? How many of them have only 1 or 2 results? To find out, we can compute the distribution of number of searches per number of search-results.
#
# Calculate the full distribution of number of searches per number of search results:

# %% [markdown]
# **Write the answer below:**

# %%
search_logs_df.result.str.len().value_counts()
# Out:
# 10    521397
# 0       7938
# 1       2142
# 2       1606
# 3       1245
# 4       1025
# 6        868
# 5        855
# 8        791
# 7        763
# 9        659
# Name: result, dtype: int64

# %%
search_logs_df.result.str.len().value_counts().plot.bar()
plt.show()

# %% [markdown]
# ### 🚩Most searched categories
#
# Find the categories with the most of number of searches. We would like to know the ID of the categories as well as their **title**.

# %% [markdown]
# **Write the answer below:**
# (Hint: we can calculate the ID of most searched categories from "search logs" dataframe, but to find their title we should also use the "categories" dataframe; hence you probably need to perform a "join"/"merge" operation to combine the information from two dataframes.)

# %%
# categories_df[search_logs_df['category_id'].value_counts().idxmax().astype(int)]
# pd.merge(categories_df, search_logs_df, on=['id', 'category_id'], how='inner')
sl_df = search_logs_df.copy()
sl_df = sl_df.dropna()
sl_df = sl_df['category_id'].astype(int)
merged_df = pd.merge(categories_df, sl_df, how='left', left_on=['id'],right_on=['category_id'])
merged_df
# Out:
#                 title    id  parent_category_id  category_id
# 0         گوشی موبایل  2580               175.0       2580.0
# 1         گوشی موبایل  2580               175.0       2580.0
# 2         گوشی موبایل  2580               175.0       2580.0
# 3         گوشی موبایل  2580               175.0       2580.0
# 4         گوشی موبایل  2580               175.0       2580.0
# ...               ...   ...                 ...          ...
# 130044  تجهیزات صنعتی  2515                 NaN       2515.0
# 130045  تجهیزات صنعتی  2515                 NaN       2515.0
# 130046  تجهیزات صنعتی  2515                 NaN       2515.0
# 130047  تجهیزات صنعتی  2515                 NaN       2515.0
# 130048  تجهیزات صنعتی  2515                 NaN       2515.0
#
# [130049 rows x 4 columns]

# %%
# merged_df.drop(['parent_category_id', 'category_id'], axis=1)
merged_df.value_counts().to_frame()[:20]
# Out:
#                                   0
# title                   id
# گوشی موبایل             2580  14960
# روغن خوراکی             3110   2647
# لپ تاپ و نوت بوک        8564   2170
# هدفون، هدست و هندزفری   1092   2110
# کارت گرافیک             820    2089
# تلویزیون                2999   1699
# کیف و کاور گوشی         9663   1223
# لوازم تزئینی خودرو      5094   1042
# کولر گازی               4476    926
# موتور سیکلت             6338    884
# ساعت و مچ بند هوشمند    3424    876
# یخچال و فریزر           5213    840
# ماشین اصلاح و ریش‌ تراش 3064    820
# لوازم خانگی             4792    762
# اسپیکر و سیستم صوتی     4087    761
# اسپرسو ساز              618     735
# کتاب و مجلات            8197    699
# پردازنده                7470    688
# مادربورد                766     684
# مانیتور                 4218    651

# %% [markdown]
# ### 🚩Number of clicks per searches
#
# We would like to know how many of the searches have gotten no clicks, or how many of them have gotten more than one clicks. To find out, we should compute the distribution of number of clicks per searches:

# %% [markdown]
# **Write the answer below:**
# (Hint: the search data and search-click data are in two different dataframes. So again we may need to perform a join/merge operation).

# %%
merged_cps_df = pd.merge(search_logs_df, search_click_logs_df, how='left', left_on=['id'],right_on=['search_id'])
merged_cps_df.search_id.isna()
# Out:
# 0         False
# 1          True
# 2          True
# 3          True
# 4         False
#           ...
# 651959     True
# 651960     True
# 651961     True
# 651962     True
# 651963     True
# Name: search_id, Length: 651964, dtype: bool

# %%
merged_cps_df.search_id.isna().sum()
# Out:
# 356272

# %%
# copy_cps = merged_cps_df.copy()
# copy_cps.search_id = copy_cps.search_id.fillna('nnnnnnnnnn')
# cps = copy_cps.search_id.value_counts()
# cps

# %%
# cps.plot.bar()
# plt.show()

# %%
n_merged_cps_df =  pd.merge(search_logs_df['id'], search_click_logs_df['search_id'], how='left', left_on=['id'], right_on=['search_id'])
count_na = n_merged_cps_df.id.count() - n_merged_cps_df.search_id.count()
p = n_merged_cps_df.search_id.value_counts().to_frame()
p = p.value_counts().to_frame()

# %%
p.loc[0, 'no clicks'] = [count_na]
p['count_on_clicks'] = p[0]
p[['no clicks', 'count_on_clicks']].plot.bar()
plt.show()

# %% [markdown]
# ### 🚩Most clicked products
#
# We are interested to know which product are the most popular. For that, we can count the clicks of each product and consider the most clicked products as the most popular ones. So let's find the top 20 most clicked products (we would like to know the ID, title and number of clicks for those products):

# %% [markdown]
# **Write the answer below:**
# (Hint: here we also need to combine information from multiple dataframes; to find the ID of clicked products, we need to consider both of "search logs" and "search clicks" dataframes, and for finding product info we additionally need the "products" dataframe.)

# %%
nl_df =  pd.merge(search_logs_df[['id', 'result']], search_click_logs_df[['search_id', 'rank']], how='left', left_on='id', right_on='search_id')
nl_df = nl_df.dropna()
nl_df['rank'] = nl_df['rank'].astype(int)
nl_df = nl_df.explode(column= 'result').reset_index()
nl_df.loc[:,'index'] = nl_df.groupby('index').cumcount()
nl_df['value'] = nl_df.apply(lambda x: x['rank'] if x['rank']==x['index'] else np.nan, axis=1)

# %%
nl_df = nl_df.dropna()
nl_df.result = nl_df.result.astype(int)

# %%
nl_df
# Out:
#          index     id   result search_id  rank  value
# 6            6  qahft  7542576     qahft     6    6.0
# 17           7  usiey  1627397     usiey     7    7.0
# 20           0  gchqj  6080642     gchqj     0    0.0
# 31           1  pesej  4538695     pesej     1    1.0
# 47           7  ufaig  6447062     ufaig     7    7.0
# ...        ...    ...      ...       ...   ...    ...
# 2935110      4  jigvf  9264053     jigvf     4    4.0
# 2935121      5  zpicq  1112947     zpicq     5    5.0
# 2935127      1  fbkkw  7220977     fbkkw     1    1.0
# 2935139      3  fbkkw  9125380     fbkkw     3    3.0
# 2935146      0  liqyi  9831020     liqyi     0    0.0
#
# [295692 rows x 6 columns]

# %%
# nl_df['id'].equals(nl_df['search_id'])
# del nl_df['id']
# del nl_df['index']
# del nl_df['value']
nl_df
# Out:
#           result search_id  rank
# 6        7542576     qahft     6
# 17       1627397     usiey     7
# 20       6080642     gchqj     0
# 31       4538695     pesej     1
# 47       6447062     ufaig     7
# ...          ...       ...   ...
# 2935110  9264053     jigvf     4
# 2935121  1112947     zpicq     5
# 2935127  7220977     fbkkw     1
# 2935139  9125380     fbkkw     3
# 2935146  9831020     liqyi     0
#
# [295692 rows x 3 columns]

# %%
p_df = products_df.copy()
p_df = p_df.rename(columns = {'id': 'result'})
p_df
# Out:
#          result                                              title  \
# 0        758287                        میکروسکوپ سلسترون مدل 44121
# 1       7164195            دوربین عکاسی نیکون مدل Nikon D5600 body
# 2       3242621        دوچرخه شهری قناری مدل Space Shuttle سایز 16
# 3       4277974         دوچرخه سایز 16 مدل  2020 Flying Bear قناری
# 4       8671305                          دوچرخه 12 قناری مدل JENNY
# ...         ...                                                ...
# 108041  1985506  اسلایم سارا در انواع طرح و نوع متنوع با کیفیت ...
# 108042  5278787           پک تخصصی کُرگیری(2دستگاه،5مته و 48سگمنت)
# 108043  8977011                       پیراهن مردانه Dior مدل 28793
# 108044  2157337                       پیراهن مردانه Dior مدل 28794
# 108045  8432560                   کیف دخترانه مدل جدید شیک کد 7929
#
#         category_id
# 0               262
# 1              1273
# 2              3882
# 3              3882
# 4              4320
# ...             ...
# 108041         4062
# 108042         3830
# 108043         4107
# 108044         4107
# 108045         4810
#
# [108046 rows x 3 columns]

# %%
the_res = pd.merge(p_df[['result', 'title']], nl_df[['result', 'search_id']], right_on='result', left_on='result')
the_res
# Out:
#          result                                              title search_id
# 0        758287                        میکروسکوپ سلسترون مدل 44121     ljvfn
# 1       7164195            دوربین عکاسی نیکون مدل Nikon D5600 body     dkwbk
# 2       7164195            دوربین عکاسی نیکون مدل Nikon D5600 body     hwqpm
# 3       3242621        دوچرخه شهری قناری مدل Space Shuttle سایز 16     azzum
# 4       3242621        دوچرخه شهری قناری مدل Space Shuttle سایز 16     emdeb
# ...         ...                                                ...       ...
# 295675  1985506  اسلایم سارا در انواع طرح و نوع متنوع با کیفیت ...     yjbjt
# 295676  5278787           پک تخصصی کُرگیری(2دستگاه،5مته و 48سگمنت)     smcro
# 295677  8977011                       پیراهن مردانه Dior مدل 28793     fqhdv
# 295678  2157337                       پیراهن مردانه Dior مدل 28794     fqhdv
# 295679  8432560                   کیف دخترانه مدل جدید شیک کد 7929     ncaja
#
# [295680 rows x 3 columns]

# %%
the_res[['title', 'result']].value_counts().to_frame()
# Out:
#                                                               0
# title                                              result
# گوشی اپل iPhone 13 Pro max (Not Active) | حافظه... 6754504  932
# گوشی شیائومی Redmi Note 11 | حافظه 128 رم 6 گیگ... 9619627  910
# روغن نیمه جامد غنجه 4کیلویی                        8783002  866
# گوشی سامسونگ A32  | حافظه 128 رم 6 گیگابایت        3233307  705
# روغن آفتابگردان غنی شده با ویتامین دی810 گرم اویلا 6018703  665
# ...                                                         ...
# سوهان حبه ای 250 گرم محمد ساعدی نیا                8201265    1
# سوهان تخت خودکار                                   9930235    1
# سوهان برقی گربه                                    5574925    1
# سوهان برقی ناخن نیل دریل NAIL DRILL DM-998         9173127    1
# 󾕇 دانلود کتاب Building A Wood-Framed Panelized ... 229572     1
#
# [108044 rows x 1 columns]

# %% [markdown]
# ### 🚩Most clicked categories
#
# And finally, we would like to know which categories of the products have the most clicks. In other words, we would like to find out products of which categories have gotten the most clicks in total. Let's find the top 10 most clicked categories, including the ID and title of the categories as well as the total number of clicks for each of those categories:

# %% [markdown]
# **Write the answer below:**
# (Hint: again, to calculate this, we need to combine the information of multiple dataframes... actually, all of them!)

# %%
one = pd.merge(p_df, nl_df[['result', 'search_id']], right_on='result', left_on='result')
one
# Out:
#          result                                              title  \
# 0        758287                        میکروسکوپ سلسترون مدل 44121
# 1       7164195            دوربین عکاسی نیکون مدل Nikon D5600 body
# 2       7164195            دوربین عکاسی نیکون مدل Nikon D5600 body
# 3       3242621        دوچرخه شهری قناری مدل Space Shuttle سایز 16
# 4       3242621        دوچرخه شهری قناری مدل Space Shuttle سایز 16
# ...         ...                                                ...
# 295675  1985506  اسلایم سارا در انواع طرح و نوع متنوع با کیفیت ...
# 295676  5278787           پک تخصصی کُرگیری(2دستگاه،5مته و 48سگمنت)
# 295677  8977011                       پیراهن مردانه Dior مدل 28793
# 295678  2157337                       پیراهن مردانه Dior مدل 28794
# 295679  8432560                   کیف دخترانه مدل جدید شیک کد 7929
#
#         category_id search_id
# 0               262     ljvfn
# 1              1273     dkwbk
# 2              1273     hwqpm
# 3              3882     azzum
# 4              3882     emdeb
# ...             ...       ...
# 295675         4062     yjbjt
# 295676         3830     smcro
# 295677         4107     fqhdv
# 295678         4107     fqhdv
# 295679         4810     ncaja
#
# [295680 rows x 4 columns]

# %%
cat_merge = pd.merge(one, categories_df, left_on='category_id', right_on='id')
cat_merge
# Out:
#          result                                     title_x  category_id  \
# 0        758287                 میکروسکوپ سلسترون مدل 44121          262
# 1       4990572          میکروسکوپ جیبی کوکین مدل Cokin 120          262
# 2       7119273      لوپ دو چشم no name صاایران مدل ZSM1001          262
# 3       7100485                    میکروسکوپ مدل mh – 450 L          262
# 4       8773026                     میکروسکوپ مدل mh -300 L          262
# ...         ...                                         ...          ...
# 295675  1356383  خودنویس پاک کن دار به همراه ۴ عدد جوهر یدک         7295
# 295676  6246279                             نخ ریسمان بنایی          420
# 295677  6764077                  ویبره سرامیک تافی مدل V-Q7         4549
# 295678  3471074          فلایویل پژو 405 سمند پارس - ایساکو         6430
# 295679  9855556                      ترازو دو کفه 20 کیلویی         1044
#
#        search_id              title_y    id  parent_category_id
# 0          ljvfn            میکروسکوپ   262               146.0
# 1          bfobm            میکروسکوپ   262               146.0
# 2          iwijn            میکروسکوپ   262               146.0
# 3          vekvt            میکروسکوپ   262               146.0
# 4          ucfyz            میکروسکوپ   262               146.0
# ...          ...                  ...   ...                 ...
# 295675     cmjeh      جوهر نوشت افزار  7295               333.0
# 295676     boymo     ریسمان کار بنایی   420              1504.0
# 295677     afkfw  ویبره کاشی و سرامیک  4549               444.0
# 295678     rbzcd        فلایویل خودرو  6430              3188.0
# 295679     njwvw     سنگ و وزنه ترازو  1044               387.0
#
# [295680 rows x 7 columns]

# %%
cat_merge[['title_x', 'result', 'category_id', 'title_y']].value_counts().to_frame()
# Out:
#                                                                                                              0
# title_x                                            result  category_id title_y
# گوشی اپل iPhone 13 Pro max (Not Active) | حافظه... 6754504 2580        گوشی موبایل                         932
# گوشی شیائومی Redmi Note 11 | حافظه 128 رم 6 گیگ... 9619627 2580        گوشی موبایل                         910
# روغن نیمه جامد غنجه 4کیلویی                        8783002 3110        روغن خوراکی                         866
# گوشی سامسونگ A32  | حافظه 128 رم 6 گیگابایت        3233307 2580        گوشی موبایل                         705
# روغن آفتابگردان غنی شده با ویتامین دی810 گرم اویلا 6018703 3110        روغن خوراکی                         665
# ...                                                                                                        ...
# سوهان حبه ای 250 گرم محمد ساعدی نیا                8201265 3485        سوهان                                 1
# سوهان تخت خودکار                                   9930235 3485        سوهان                                 1
# سوهان برقی گربه                                    5574925 6948        سایر تجهیزات نگهداری حیوانات خانگی    1
# سوهان برقی ناخن نیل دریل NAIL DRILL DM-998         9173127 9312        پدیکور و مانیکور                      1
# 󾕇 دانلود کتاب Building A Wood-Framed Panelized ... 229572  7454        کتاب های صوتی و الکترونیکی            1
#
# [108044 rows x 1 columns]
